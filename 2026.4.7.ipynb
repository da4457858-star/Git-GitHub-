# %%
# ch5_5.py
print("your score")
score = input("put in")
sc = int(score)
if (sc >= 90 ):
     print(" A") 
elif (sc >= 80 ):
     print(" B") 
elif (sc >= 70 ):
     print(" C") 
elif (sc >= 60 ):
     print(" D") 
else:
     print(" F")
# Out:
# your score
# put in 90
#  A

# %%
#5-1
print("your age")
age = input("put in")
year = int(age)-1900
rem = year % 12
if (rem == 0 ):
     print(" mice") 
elif (rem == 1 ):
     print(" cow") 
elif (rem == 2 ):
     print(" tiger") 
elif (rem == 3 ):
     print(" rabbit") 
elif (rem == 4 ):
     print(" dragon") 
elif (rem == 5 ):
     print(" snake") 
elif (rem == 6 ):
     print(" horse") 
elif (rem == 7 ):
     print(" goat") 
elif (rem == 8 ):
     print(" monkey") 
elif (rem == 9 ):
     print(" rooster") 
elif (rem == 10 ):
     print(" dog") 
elif (rem == 11 ):
     print(" pig")
# Out:
# your age
# put in 1911
#  pig

# %%
#ch5-6py.
print("tichet")
age = input("put in")
age = int(age)
ticket = 100
if (age <= 6):
    print(" ticket=20") 
elif (age >= 80 ):
    print(" ticket=20") 
elif (age >= 60) and (age <=79 ):
    print(" ticket=50") 
elif (age >= 7 )and (age <= 12 ):
    print(" ticket=50") 
else:
     print(" ticket=100")
# Out:
# tichet
# put in 55
#  ticket=100

# %%
#6-1
james = [90, 85, 75, 65, 44]
print("first student score", james[0])
# Out:
# first student score 90

# %%
#ch6-8.py
james = [23, 19, 22, 31, 18]
print("max=", max(james))
print("min=", min(james))
print("sum=", sum(james))
# Out:
# max= 31
# min= 18
# sum= 113

# %%
james = [100, 80, 90, 70, 85, 88, 77, 60, 50, 97]
print("max(2-7)=", max(james[1:7]))
print("min=(2-7)", min(james[1:7]))
# Out:
# max(2-7)= 90
# min=(2-7) 70
