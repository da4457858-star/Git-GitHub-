# %%
james = [90, 80, 88, 84, 85, 87, 88, 89, 90, 100]
james[0]=james[0]+10
james[9]=james[9]-10
print("new score", james)
# Out:
# new score [100, 80, 88, 84, 85, 87, 88, 89, 90, 90]

# %%
score=[]
print("now=", score)
score.append('80')
print("now=", score)
score.append('70')
print("now=", score)
score.append('60')
print("now=", score)
# Out:
# now= []
# now= ['80']
# now= ['80', '70']
# now= ['80', '70', '60']

# %%
score = [80, 90, 85, 75, 70, 65, 88, 98, 100]
print("max=", max(score))
print("min=", min(score))
print("all=", sum(score))

score.append(59)
score.append(99)
print("now=", score)
score.sort(reverse=True)
print("big to small=", score)
score.sort(reverse=not True)
print("small to big=", score)
# Out:
# max= 100
# min= 65
# all= 751
# now= [80, 90, 85, 75, 70, 65, 88, 98, 100, 59, 99]
# big to small= [100, 99, 98, 90, 88, 85, 80, 75, 70, 65, 59]
# small to big= [59, 65, 70, 75, 80, 85, 88, 90, 98, 99, 100]

# %%
fruits = ['apple', 'banana' , 'watermelon']
fruit = input("write fruit = " ) 
if fruit in fruits:
    print("this fruit is have")
else:
    fruits.append(fruit)
    print("add it in the list: ", fruits)
# Out:
# write fruit =  orange
# add it in the list:  ['apple', 'banana', 'watermelon', 'orange']

# %%
scores = ['90', '88', '75', '64', '33', '22', '97',]
for score in scores :
    print(score)
# Out:
# 90
# 88
# 75
# 64
# 33
# 22
# 97
