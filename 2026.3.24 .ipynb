# %%
print("hello world")
# Out:
# hello world

# %%
x = 5
y = 9
z = "hello world"
print("x=",x,type(x))
print("y=",y,type(y))
print("z=",z,type(z))
# Out:
# x= 5 <class 'int'>
# y= 9 <class 'int'>
# z= hello world <class 'str'>

# %% [markdown]
# ###ch3_25py

# %%
# ch3_25py
dist = 384400
speed = 1225
total_hours = dist // speed
days = total_hours // 24
hours = total_hours % 24
print("total need days")
print(days)
print("total need hours")
print(hours)
# Out:
# total need days
# 13
# total need hours
# 1

# %% [markdown]
# ###

# %%
dist = 10000
speed = 1225
total_hours = dist // speed
days = total_hours // 24
hours = total_hours % 24
print("total need days")
print(days)
print("total need hours")
print(hours)
# Out:
# total need days
# 0
# total need hours
# 8

# %% [markdown]
# ###ch3_16py

# %%
# ch3_16py
print("wellcome to use")
name = input("username:")
engh = input("ENGLISH grade:")
math = input("math grade:")
chin = input("chinese grade:")
natu = input("nature grade:")
total = int(engh) + int(math) + int(chin) + int(natu)
print("%s your total grade %d" % (name, total))
# Out:
# wellcome to use
# username: dada
# ENGLISH grade: 100
# math grade: 80
# chinese grade: 95
# nature grade: 75
# dada your total grade 350

# %% [markdown]
# ###huashi

# %%
# ch4_20py
f = float(input("fahrebheit :"))
c = ( f - 32 ) * 5 / 9
print("huashi %4.1f dengyushesshi %4.1f" % (f,c))
# Out:
# fahrebheit : 105
# huashi 105.0 dengyushesshi 40.6

# %% [markdown]
# ### ch5_4.py

# %%
#ch5_4.py
print("judge odd or even numbers")
num = input("renyishuzhi: ")
rem = int(num) % 2
if (rem == 0 ):
    print("%s is odd number" % int(num))
else:
    print("%s is even number" % int(num))
# Out:
# judge odd or even numbers
# renyishuzhi:  5
# 5 is even number
